# %% [markdown]
# # Task Modelling & Real-World Model Performance: Analysing Shopify
#
# The following notebook aims at providing an entry point to the aspects of task modelling: Thinking about how ML models can be applied to be useful for real-world tasks.
#
# An important aspect concerning application scenarios is the real-world performance of models that we can observe.
#
# To evaluate these two aspects the notebook is configured to download and process data from Shopify, a No Code e-commerce platform.
#
# The starting point for the analysis is given by the description of these shops and the application of a trained Named Entity (NE) model to extract the key entities from these descriptions.

# %% [markdown]
# # Install Necessary Models and Modules
#
# The following code cell downloads a python module and a machine learning model.

# %%
# the following command downloads a model for spacy (a machine learning library focused on text processing)
# !python -m spacy download en_core_web_sm
# !wget https://github.com/eg-bfh/PoML/raw/main/Top10KShopify.csv
# Out:
# 2022-11-29 14:58:59.939830: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
#      |████████████████████████████████| 12.8 MB 4.6 MB/s
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from en-core-web-sm==3.4.1) (3.4.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.23.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.10.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.10)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (57.4.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.4.5)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.3)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.8.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.9)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.11.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (21.3)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.1.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.64.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.7)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.10.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.10)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.7/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.7/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# --2022-11-29 14:59:06--  https://github.com/eg-bfh/PoML/raw/main/Top10KShopify.csv
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/eg-bfh/PoML/main/Top10KShopify.csv [following]
# --2022-11-29 14:59:07--  https://raw.githubusercontent.com/eg-bfh/PoML/main/Top10KShopify.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4591708 (4.4M) [text/plain]
# Saving to: ‘Top10KShopify.csv.1’
#
# Top10KShopify.csv.1 100%[===================>]   4.38M  --.-KB/s    in 0.02s
#
# 2022-11-29 14:59:07 (253 MB/s) - ‘Top10KShopify.csv.1’ saved [4591708/4591708]

# %%
# we import the pandas library that helps us to parse the CSV file and provides us with a dataframe (generally a table data structure).
import pandas as pd

# %%
# We read the data and keep only the rows where the site description is not null
shopify_df = pd.read_csv(r'Top10KShopify.csv');
shopify_desc_df = shopify_df[shopify_df['Site Description'].notnull()]

# %% [markdown]
# ## Exercise: NE Extraction on Shopify Descriptions
#
# The following cell loads a machine learning model and applies it in order to extract Named Entities from the shop Descriptions.
#
# The model that is used is the 'en_core_web_sm' model, where 'sm' stands for small.
#
# You can visit the following page to get more information about the available models:
#
# https://spacy.io/models/en

# %%
# Extract Named Entities with spacy
import spacy
nlp = spacy.load("en_core_web_sm")

from prettytable import PrettyTable, ALL
t = PrettyTable(['Shop Description', 'Named Entities'])
t.hrules=ALL
from textwrap import fill


for doc in nlp.pipe(shopify_desc_df.sample(n=100)['Site Description']):
    # Do something with the doc here
    t.add_row([fill(f"{doc}", width=50),fill(f"{[(ent.text, ent.label_) for ent in doc.ents]}", width=40)])

print(t)
# Out:
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                                       Shop Description                                      |            Extracted Keywords            |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                         Australia's Offical Panini NBA Distributor -                        |   [('Australia', 'GPE'), ('- Pokemon',   |
# |                      Pokemon, YuGiOh! Magic The Gathering Trading Cards                     |                'PERSON')]                |
# |                      - Buy Direct and Save - Sell Your Cards - Beckett                      |                                          |
# |                                         BGS Grading                                         |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                         Established in 1985, Bookazine, a family run                        | [('1985', 'DATE'), ('Bookazine', 'ORG'), |
# |                        business, is Hong Kong's best and friendliest                        |   ("Hong Kong's", 'GPE'), ('English',    |
# |                        general-purpose bookstore. The company prides                        |               'LANGUAGE')]               |
# |                       itself in offering the best selection of English                      |                                          |
# |                       language books and magazines, stationery, cards,                      |                                          |
# |                       gifts, toys and sweets. Visit our stores or shop                      |                                          |
# |                                           online!                                           |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                        متجر فاء ، متجر لمنتجات الصحة والعناية الشخصية                       |  [('لمنتجات الصحة والعناية', 'PERSON'),  |
# |                      الأصلية ، نهتم بتوفير منتجات العناية بالجسم والشعر                     | ('، نهتم', 'PERSON'), ('بتوفير', 'GPE'), |
# |                         والبشرة والتجميل والعناية بالأطفال والعناية                         |  ('منتجات العناية', 'PERSON'), ('بالجسم  |
# |                       بالمنزل ونوفر كافة المستلزمات الطبية ، كما نسعى                       | والشعر والبشرة', 'PERSON'), ('احتياجات', |
# |                       لأن نكون خيارك الأول في احتياجات حياتك اليومية.                       |   'GPE'), ('حياتك اليومية', 'PERSON')]   |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                       A site for the caregivers. Shop for home health                       |                    []                    |
# |                      equipment and durable medical equipment for those                      |                                          |
# |                             who need living assistance at home.                             |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      Crossover International is premium online shopping                     |   [('Crossover International', 'ORG'),   |
# |                         experience. We proudly stock brands such as                         |  ('Replay', 'ORG'), ('Diesel', 'ORG'),   |
# |                           Replay, Kaporal, Diesel, Vialli, Roberto                          |       ('Vialli', 'GPE'), ('Roberto       |
# |                      Botticelli, Gas, Versace, Roberto Cavalli and many                     |   Botticelli', 'PERSON'), ('Versace',    |
# |                                   more world class brands.                                  |  'ORG'), ('Roberto Cavalli', 'PERSON')]  |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                       Introducing the most accurate body Smart Scale.                       |   [('Smart Scale', 'PERSON'), ('BMI',    |
# |                        Understand your body better with a smart scale                       |                 'ORG')]                  |
# |                       that automatically tracks weight, body fat, BMI                       |                                          |
# |                                 and lean mass and shows you                                 |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                        Des coques de téléphone qui s'inspirent de la                        |   [('de proposer des design uniques et   |
# |                           richesse des cultures africaines et afro                          |          originaux', 'PERSON')]          |
# |                      descendantes, afin de proposer des design uniques                      |                                          |
# |                                        et originaux.                                        |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                       The Preferred Standing Desk brand in Singapore,                       |   [('Singapore', 'GPE'), ('thousands',   |
# |                      trusted & review by thousands. Exceptional quality                     |               'CARDINAL')]               |
# |                      at industry-disruptive prices - height adjustable                      |                                          |
# |                        desks should be affordable and yet able to be                        |                                          |
# |                       customised to fit any spaces at homes or offices                      |                                          |
# |                         and anyone from professionals & creatives to                        |                                          |
# |                               students for work and for play.                               |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      Pick-Pocket Proof® Travel Clothing: Secure urban /                     |      [('Pick-Pocket Proof', 'ORG')]      |
# |                      outdoor travel pants, shirts & jackets w/ built-in                     |                                          |
# |                        hidden zippered pockets to prevent theft while                       |                                          |
# |                                          traveling.                                         |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                       Elevate your healthy routine with the best slow                       |       [('monthly', 'DATE'), ('48',       |
# |                        juicers. Shop now and pay later! Easy monthly                        |     'CARDINAL'), ('0%', 'PERCENT')]      |
# |                       payment plan available. Shop the best cold press                      |                                          |
# |                         juicer for your family. Free shipping to 48                         |                                          |
# |                          contiguous states. 0% financing available.                         |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                         Shop Handmade Jewellery at Temple of the Sun                        | [('Shop Handmade Jewellery', 'PERSON'),  |
# |                       Australia. Sign Up For 10% OFF Your First Order.                      | ('Temple of the Sun Australia', 'ORG'),  |
# |                      Free Express Delivery On Domestic Orders Over $200                     |  ('10%', 'PERCENT'), ('200', 'MONEY')]   |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      Growing Ashwagandha biodynamically and processing                      | [('Ashwagandha', 'ORG'), ('Ashwagandha', |
# |                       alchemically the worlds finest Ashwagandha into                       | 'PERSON'), ('Fresh Ashwagandha Spagyric  |
# |                       our vibrant Fresh Ashwagandha Spagyric Tincture.                      |            Tincture', 'ORG')]            |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                         World's first 100% compostable, eco-friendly                        |          [('100%', 'PERCENT')]           |
# |                       sunglasses working towards plastic free oceans!                       |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                        Our seed to shelf, full-spectrum CBD products                        |      [('the Hudson Valley', 'LOC')]      |
# |                        support health and wellness for your mind and                        |                                          |
# |                         body. Our full-spectrum hemp is grown in the                        |                                          |
# |                                        Hudson Valley.                                       |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                         Chi Chi London aims to bring catwalk fashion                        |      [('Chi Chi London', 'PERSON'),      |
# |                      direct to the high street with our gorgeous range                      | ('Cocktail, Prom, Evening and', 'ORG'),  |
# |                         of Cocktail, Prom, Evening and Maxi Dresses                         |         ('Maxi Dresses', 'ORG')]         |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                         Blossom Wedding, Disney Fairy Tale Weddings,                        | [('Blossom Wedding', 'PERSON'), ('Disney |
# |                        Disbride, Bridal Shop, Wedding Service, Bridal                       |     Fairy Tale Weddings', 'PERSON'),     |
# |                      Chaperone, Chinese Wedding, Evening Dress, Wedding                     |   ('Disbride', 'ORG'), ('Bridal Shop',   |
# |                      Photography, Wedding Makeup Artist. Wedding Dress,                     |   'ORG'), ('Bridal Chaperone', 'ORG'),   |
# |                                         Bridal Dress                                        |  ('Chinese', 'NORP'), ('Bridal Dress',   |
# |                                                                                             |                 'ORG')]                  |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      Velaasa designs and develops innovative footwear,                      |     [('Velaasa', 'GPE'), ('Olympic',     |
# |                         training gear and apparel for Olympic sport                         |                'EVENT')]                 |
# |                                          athletes.                                          |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                        The Anime Shop - Howdy Otaku!! Looking for the                       |    [('The Anime Shop - Howdy Otaku',     |
# |                        best anime merchandise? you have landed at the                       |                 'ORG')]                  |
# |                       right place. Our anime & manga online store has                       |                                          |
# |                       everything for you. Our lines of anime merch are                      |                                          |
# |                       all based on all your favorite anime characters.                      |                                          |
# |                      Anime is our love and we make sure to provide only                     |                                          |
# |                                     top-quality product.                                    |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                         Formally Art of Homage - High end Christian                         |    [('Formally Art of Homage - High',    |
# |                        apparel brand for the modern believer. We are                        |    'PERSON'), ('Christian', 'NORP'),     |
# |                      culture. We are Christian. Christian Accessories.                      |   ('Christian', 'NORP'), ('Christian',   |
# |                                     Christian Clothing.                                     |     'NORP'), ('Christian Clothing',      |
# |                                                                                             |                'PERSON')]                |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      Focus SUP Hawaii carries the best stand up paddle                      |  [('Focus SUP Hawaii', 'ORG'), ('SUP',   |
# |                      boards and paddleboard accessories. Buy online the                     |    'ORG'), ('today', 'DATE'), ('818',    |
# |                       best SUP boards for any level today. Call (818)                       |               'CARDINAL')]               |
# |                                           765-4511                                          |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      Shop our large selections of fine Native American                      | [('Native American', 'NORP'), ('Indian', |
# |                      Indian jewelry, Pueblo pottery, Zuni fetishes, and                     |                 'NORP')]                 |
# |                            more! From the Pueblo, Direct to You.                            |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                        Buy custom passion apparel, which is Indian in                       |           [('Indian', 'NORP')]           |
# |                       taste and completely customised to your passion                       |                                          |
# |                        and interests.Products available are t-shirts                        |                                          |
# |                                     ,hoodies phone case                                     |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      Rex Specs are protective dog goggles designed for                      |        [('Rex Specs', 'PERSON')]         |
# |                        the active and working dog. Protect your dog's                       |                                          |
# |                                   eyes from the elements.                                   |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      Worldwide Shipping. Miniatures for tabletop games.                     |    [('elven', 'ORG'), ('Clay Project     |
# |                           High quality resin miniatures, painting                           |           Miniatures', 'ORG')]           |
# |                         miniatures, lizardmen, orcs, elven, trolls,                         |                                          |
# |                          dragons, wizards. Clay Project Miniatures.                         |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                        Gemstone Yoni produces the most authentic yoni                       |                    []                    |
# |                        eggs, yoni wands and beauty tools made of pure                       |                                          |
# |                      crystal. Spiritually Nourishing Women all over the                     |                                          |
# |                                       globe. Shop Now                                       |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      Innovative Stainless Steel Facial Rollers and Gua                      |   [('Innovative Stainless Steel Facial   |
# |                      Tools, Founded by Sarah Cheung. We are reimagining                     |     Rollers', 'ORG'), ('Gua Tools',      |
# |                       beauty routines with our innovative beauty tools                      |  'PERSON'), ('Sarah Cheung', 'PERSON')]  |
# |                            and skincare collection. SACHEU Beauty                           |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      The most stylish, fun diffuser & air humidifier on                     |       [('diffuser & air', 'ORG')]        |
# |                          the market. Provides a constant source of                          |                                          |
# |                       moisture, helping soothe itchy skin, congestion,                      |                                          |
# |                       and other problems caused by dry air. Ultrasonic                      |                                          |
# |                      cool wave technology and compatible with essential                     |                                          |
# |                                            oils.                                            |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                        Stag Motorcycles, LMX UK, Sur-ron, Cake Bikes,                       | [('LMX UK', 'ORG'), ('Sur-ron', 'ORG'),  |
# |                          Horwin, Artisan scooter, Artisan Electric,                         |   ('Cake Bikes', 'PERSON'), ('Horwin',   |
# |                         Electric motorbike, Electric Mountain bike,                         | 'PERSON'), ('Artisan Electric', 'ORG'),  |
# |                                     Electric motorcycles                                    |      ('Electric Mountain', 'ORG')]       |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      Only 3g of sugar, 90 calories and 6g net carbs per                     |     [('Only 3', 'CARDINAL'), ('90',      |
# |                           bag. Crafted by chefs. 100% Satisfaction                          | 'CARDINAL'), ('6', 'CARDINAL'), ('100%', |
# |                      Guaranteed. Keto Candy that's Low-Sugar, Non-GMO,                      |  'PERCENT'), ('Keto Candy', 'PERSON'),   |
# |                       Gluten-Free, Grain-Free, Wheat-Free, Dairy-Free,                      |    ('Low-Sugar', 'ORG'), ('Non-GMO',     |
# |                       Nothing Artificial, No Sugar Alcohols, Naturally                      | 'ORG'), ('Gluten-Free', 'ORG'), ('Grain- |
# |                      Sweetened, Kosher Gelatin, Natural Colors, Natural                     |   Free', 'ORG'), ('Dairy-Free, Nothing   |
# |                                 Flavors, and Keto Friendly.                                 |     Artificial', 'ORG'), ('Naturally     |
# |                                                                                             |     Sweetened', 'PERSON'), ('Kosher      |
# |                                                                                             | Gelatin', 'PERSON'), ('Natural Colors',  |
# |                                                                                             |   'ORG'), ('Keto Friendly', 'PERSON')]   |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                       Danse Lente is a women’s handbags & accessories                       |           [('London', 'GPE')]            |
# |                       label specializing in handbags and small leather                      |                                          |
# |                      goods, based in London. Each piece is conceived in                     |                                          |
# |                       depth in order to create a purpose built product                      |                                          |
# |                       that will also create a unique experience to its                      |                                          |
# |                                         predecessor.                                        |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                       Ranging from full costumes to small accessories,                      |  [('Halloween', 'DATE'), ('Halloween',   |
# |                      outdoor and indoor decorations, at SpookyForYou it                     |     'DATE'), ('Halloween', 'DATE'),      |
# |                      is our mission to provide everything you need for                      |           ('holiday', 'DATE')]           |
# |                        an amazing Halloween. Thanks to us, Halloween                        |                                          |
# |                         doesn't have to be boring anymore! Shop our                         |                                          |
# |                      collection of ready to ship Halloween specials to                      |                                          |
# |                                    spice up your holiday!                                   |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                            Souqcart.com offers the best prices on                           | [('Souqcart.com', 'ORG'), ('thousands',  |
# |                       electronics, computer, laptop computers, LED LCD                      |               'CARDINAL')]               |
# |                        TVs, home appliances, digital cameras, mobile                        |                                          |
# |                        phones, video games, office supplies, and more                       |                                          |
# |                      with fast and free shipping on thousands of items                      |                                          |
# |                               and top-rated customer service.                               |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                       We offer high quality, luxurious and comfortable                      |  [('Bed Sheets', 'PERSON'), ('Shopping   |
# |                          Bed Sheets at affordable price compared to                         |            Malls', 'PERSON')]            |
# |                                       Shopping Malls.                                       |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |     さまざまな熱電対や最先端の水耕システムとともに、高定格のサーマルカメラ製品の本拠地。    |                    []                    |
# |                                     送料無料-60日間保証                                     |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                        Home to the high rated thermal camera products                       |          [('60 days', 'DATE')]           |
# |                      along with various thermocouples and state of the                      |                                          |
# |                        art hydroponic system. Free Shipping - 60 days                       |                                          |
# |                                          Guarantee                                          |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                             Your favorite YouTuber has a line of                            |          [('YouTuber', 'ORG'),           |
# |                      UnspeakableGaming merch, featuring t-shirts, hats,                     |      ('UnspeakableGaming', 'ORG'),       |
# |                             hoodies, and accessories. Represent                             |     ('Represent UnspeakableGaming',      |
# |                      UnspeakableGaming with these awesome items today.                      |      'PERSON'), ('today', 'DATE')]       |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                       The ultimate women's bags designed to carry you                       |  [('daily', 'DATE'), ('hour', 'TIME'),   |
# |                      through your day. Fitting like puzzle pieces, you                      |            ('5', 'CARDINAL')]            |
# |                        can rework your bag just like you rework your                        |                                          |
# |                       daily schedule. Take us to work, to the gym, to                       |                                          |
# |                          happy hour, or as a carry on on your next                          |                                          |
# |                          adventure! Our 5 piece Fundamentals set is                         |                                          |
# |                            everything you didn't know you needed.                           |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      Bunker Branding Co. is an online merchandise store                     |     [('Bunker Branding Co.', 'ORG'),     |
# |                      for all of your favorite Social Media Influencers.                     |   ('Social Media Influencers', 'ORG'),   |
# |                        From YouTube, Instagram, Twitter, etc. We also                       |    ('YouTube', 'ORG'), ('Instagram',     |
# |                          create custom apparel and merchandise for                          |       'ORG'), ('Twitter', 'GPE')]        |
# |                              businesses and individual brands.                              |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                        At Morii Fash, you'll find trendy apparel that                       |        [('Morii Fash', 'PERSON')]        |
# |                      you'll love. We offer all sizes in our collections                     |                                          |
# |                                       on our website.                                       |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                          SHOP PROG & METAL at Wild Thing Records |                          |    [('SHOP PROG & METAL at', 'ORG'),     |
# |                       Caligula's Horse, Circles, The Ocean, Skyharbor,                      |   ('Caligula', 'PERSON'), ('Circles',    |
# |                      Monuments, City Of Souls, PROGFEST, AlithiA | CDs,                     | 'GPE'), ('Ocean', 'LOC'), ('Monuments',  |
# |                          Vinyl, T-Shirts, Merch from your favourite                         |  'GPE'), ('AlithiA', 'ORG'), ('Vinyl',   |
# |                               progressive rock & metal bands.                               |                'PERSON')]                |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                       Buy luxury intimates and activewear online today                      |    [('today', 'DATE'), ('Ivysister',     |
# |                        with Ivysister. Chic styles and gorgeous sets                        |  'ORG'), ('Shop Ivysister', 'PERSON')]   |
# |                        available. Dont miss out. Shop Ivysister Now!                        |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      KINGDOM59 is your go to for great deals on premium                     |      [('KINGDOM59', 'ORG'), ('80%',      |
# |                      golf gear up to 80% off. Ready to ship collection                      | 'PERCENT'), ('24 Hour', 'TIME'), ('99',  |
# |                      of goods. 24 Hour Free Shipping over $99. Join us.                     |       'MONEY'), ('Deals', 'ORG')]        |
# |                       Enjoy the Deals. Enjoy the gear. Enjoy the Game.                      |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                        Online guitar store specializing in New, Used,                       | [('Custom and Vintage Guitars', 'ORG'),  |
# |                      Custom and Vintage Guitars. Gibson, Fender, Taylor                     |  ('Gibson, Fender,', 'ORG'), ('Taylor &  |
# |                        & Martin Dealer! Safe & secure checkout, fast                        | Martin Dealer', 'ORG'), ('Safe & secure  |
# |                         shipping and financing available. Visit our                         |    checkout', 'ORG'), ('Farmingdale',    |
# |                       incredible showroom in Farmingdale, New York on                       |   'GPE'), ('New York', 'GPE'), ('Long    |
# |                        Long Island. Trades and consignments welcome!                        | Island', 'LOC'), ('Authorized Service &  |
# |                             Authorized Service & Guitar Repairs!                            |         Guitar Repairs', 'ORG')]         |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                           Los Angeles Apparel is a basics apparel                           |  [('Los Angeles Apparel', 'ORG'), ('Dov  |
# |                         manufacturer and distributor founded by Dov                         |    Charney', 'PERSON'), ('American',     |
# |                         Charney, a long-standing leader in American                         |                 'NORP')]                 |
# |                                    garment manufacturing.                                   |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                         Shop our wide range of Cheap and Affordable                         |     [('20', 'MONEY'), ('#1 Online',      |
# |                         sunglasses now. Everything $20 and Under. #1                        |  'MONEY'), ('5', 'MONEY'), ('$30 Code',  |
# |                      Online Store for sunglasses and accessories. Shop                      | 'MONEY'), ('5', 'MONEY'), ('Sunglasses', |
# |                       our SALE with $5 off $30 Code. Order now and get                      |    'WORK_OF_ART'), ('iPhone', 'ORG'),    |
# |                      $5 2-3 Day Priority shipping. SHOP fashionable and                     |  ('Samsung Accessories', 'ORG'), ('Gold  |
# |                          affordable Sunglasses, iPhone and Samsung                          |   Plated Jewelry', 'ORG'), ('Knee High   |
# |                      Accessories, Gold Plated Jewelry, Knee High Socks,                     |  Socks', 'PERSON'), ('Hats', 'PERSON')]  |
# |                                        Hats and MORE!                                       |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                       Kilt Experts is a leading supplier, manufacturer                      |  [('Kilt Experts', 'ORG'), ('Scottish',  |
# |                        and wholesaler of custom made kilts and kilts                        |                 'NORP')]                 |
# |                          accessories. We offer a huge collection of                         |                                          |
# |                               Scottish kilts, utility, tartan,                              |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                       The Truth Beauty Company is a one stop shop for                       |  [('The Truth Beauty Company', 'ORG'),   |
# |                        the finest selection of affordable natural and                       |           ('one', 'CARDINAL')]           |
# |                       organic skin care beauty products, hair care and                      |                                          |
# |                                 cosmetic brands. Visit Now!                                 |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      Military Energy Gum stops fatigue instantly, it's                      |          [('100', 'CARDINAL')]           |
# |                      clinically proven to improve: cognitive abilities,                     |                                          |
# |                         marksmanship, physical performance, overall                         |                                          |
# |                      vigilance. Strongest caffeine gum made, 100mg per                      |                                          |
# |                                            piece.                                           |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                        Your one-stop shop for all things inshore and                        | [('one', 'CARDINAL'), ('Tackle', 'GPE')] |
# |                          offshore fishing! Tackle, gear, clothing,                          |                                          |
# |                                    electronics and more!                                    |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                         Teddy Fresh Official. Clothing, Sweatshirts,                        |           [('Hoodies', 'GPE')]           |
# |                       Hoodies, Jackets, T-Shirts, Socks, Accessories.                       |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                        Shop the best Weighted Blankets & Acupressure                        |    [('Weighted Blankets & Acupressure    |
# |                        Mats, help people with Stress, Anxiety, ADHD,                        |  Mats', 'ORG'), ('Insomnia & Sensory',   |
# |                      Insomnia & Sensory issues. Relax faster, calm down                     |                 'ORG')]                  |
# |                                    easier, sleep deeper.                                    |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                         Canada's best selection of Japanese Knives,                         |     [('Canada', 'GPE'), ('Japanese',     |
# |                       sharpening stones, and chef's tools. Mail-in and                      |                 'NORP')]                 |
# |                        in-store knife sharpening services available.                        |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                        Famous for the green Heart in Oregon sticker.                        | [('Oregon', 'GPE'), ('America', 'GPE'),  |
# |                      Also, Heart in America, Heart in your home state,                      |  ('Bigfoot', 'PERSON'), ('Yeti & Heart   |
# |                       Bigfoot, Yeti & Heart Sticker designs. T-shirts,                      |    Sticker', 'ORG'), ('pint & wine',     |
# |                      hats, mugs, pint & wine glasses, patches and more.                     | 'ORG'), ('Portland', 'GPE'), ('Oregon',  |
# |                      Based in Portland, Oregon, featuring founder Chris                     |    'GPE'), ('Chris Bucci', 'PERSON'),    |
# |                         Bucci designs, including Texas, Washington,                         | ('Texas', 'GPE'), ('Washington', 'GPE'), |
# |                                  California, Colorado, USA.                                 |   ('California', 'GPE'), ('Colorado',    |
# |                                                                                             |         'GPE'), ('USA', 'GPE')]          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      America's Favourite shapewear brand Feel Confident                     | [('America', 'GPE'), ('Feel Confident',  |
# |                      In Our High Quality Waist Trainer , waistshapers.                      |    'PERSON'), ('Selling Shape-Wear',     |
# |                                   Best Selling Shape-Wear                                   |                'PERSON')]                |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      Jinen offers imported Japanese goods for the home                      | [('Jinen', 'GPE'), ('Japanese', 'NORP')] |
# |                      and kitchen + more. Modern, minimal, and timeless.                     |                                          |
# |                       We hand select fine goods that bring tranquility                      |                                          |
# |                                   and value to your life.                                   |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                        We don't fake it, we make it. Our deep love of                       |  [('Dressings &', 'ORG'), ('Marinades',  |
# |                       plants, and the belief that eating more of them                       |     'ORG'), ('organic &amp', 'ORG')]     |
# |                         makes good sense, led us to create a line of                        |                                          |
# |                         Dressings &amp; Marinades that use only the                         |                                          |
# |                      highest quality organic &amp; non-GMO ingredients                      |                                          |
# |                        we can find. We do this because it’s the right                       |                                          |
# |                           thing to do. Always just the raw goods.                           |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                       A boutik that delivers luxe and an upper-echelon                      |                    []                    |
# |                              experiences at reasonable prices.                              |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                        Muscle Republic is a motivational fitness and                        |  [('Muscle Republic', 'GPE'), ('achieve  |
# |                        lifestyle brand where friendship and community                       |          healthier', 'PERSON')]          |
# |                         reign supreme to achieve healthier, happier                         |                                          |
# |                      lifestyles. We create high quality, functional and                     |                                          |
# |                      stylish apparel for passionate individuals united                      |                                          |
# |                        through a belief in the positive influence of                        |                                          |
# |                                           fitness.                                          |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                       Delicious milk chocolate with the same amount of                      |      [('Joe', 'PERSON'), ('250 ml',      |
# |                      caffeine in a regular cup o' Joe or 250 ml energy                      |               'QUANTITY')]               |
# |                      drink—a real eye-popping treat. Give it a go, eh?                      |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                          Cendré pays homage to the timelessness of                          |         [('Parisienne', 'GPE')]          |
# |                          Parisienne opulence and the simplicity of                          |                                          |
# |                      contemporary minimalism. At its essence the brand                      |                                          |
# |                       is about trans-seasonal handcrafted pieces made                       |                                          |
# |                      from carefully selected materials; minimal pieces                      |                                          |
# |                        elevated by delicate details. Specialising in                        |                                          |
# |                                  Necklaces, Earrings & Bags                                 |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                        At RMR Solutions we simplify cleaning mold and                       |  [('RMR Solutions', 'FAC'), ('seconds',  |
# |                        mildew through our ultra-fast stain removers,                        |                 'TIME')]                 |
# |                        designed to clean stains from mold and mildew                        |                                          |
# |                                       within seconds!                                       |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                          Shop 2(X)IST for men's designer underwear,                         |                    []                    |
# |                           swimwear, apparel, accessories and more.                          |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# ...
# |                          Ring, Necklaces, Earrings, Bracelets. Free                         |                                          |
# |                            shipping on $150+. Afterpay accepted.                            |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      Designer swimwear without the designer price tag!                      |  [('5x', 'CARDINAL'), ('95', 'MONEY')]   |
# |                       5x stronger (and cuter) than your ordinary suit.                      |                                          |
# |                                   Everything is under $95.                                  |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      Halloween Costumes, Halloween Masks, Clown, Zombie                     |  [('Halloween', 'DATE'), ('Halloween',   |
# |                      and other scary masks an costumes at great prices.                     |  'DATE'), ('Clown', 'GPE'), ('Zombie',   |
# |                          Shop the best Halloween store online now.                          |      'GPE'), ('Halloween', 'DATE')]      |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# | TREND.HK 潮科技，以新潮科技的硬件產品為主軸，集合最新科技和娛樂資訊於一身，旗下網上商店售賣 |                    []                    |
# |                                 最新科技、娛樂、電玩等產品。                                |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      Unleash your inner Goddess, your place to save on                      |  [('Goddess', 'PRODUCT'), ('Goddesses',  |
# |                      the most trending deals online, we strive to find                      |                'PERSON')]                |
# |                         the best deals to all our fellow Goddesses.                         |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      Melbourne based boutique clothing store with free                      |   [('Melbourne', 'ORG'), ('Australia',   |
# |                      express shipping Australia wide for all girls and                      |                 'GPE')]                  |
# |                      womens clothing and fashion items. Fast delivery,                      |                                          |
# |                                          best price                                         |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      Thoughtfully selected indoor plants, planters and                      |                    []                    |
# |                       accessories that balance home design with a hint                      |                                          |
# |                                     of what grows wild.                                     |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                       STRAYE is a footwear brand with the most durable                      |           [('STRAYE', 'ORG')]            |
# |                      skate shoe. Offering unique styles that allow you                      |                                          |
# |                      to be forward, fluid and unexpected. Tread loudly!                     |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                           Shop Mikasa for a variety of bone china,                          |  [('Shop Mikasa', 'PERSON'), ('china',   |
# |                            dinnerware sets, drinkware & flatware.                           | 'GPE'), ('drinkware & flatware', 'ORG')] |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      Accessori d'abbigliamento moda per uomo realizzate                     |    [('Cravatte', 'ORG'), ('sciarpe',     |
# |                        a mano. Cravatte, papillon, pochette e sciarpe                       |  'GPE'), ('siciliane 100%', 'PERCENT'),  |
# |                       siciliane 100% Made in Italy. Graffeo Cravatte è                      |  ('Italy', 'GPE'), ('Graffeo Cravatte',  |
# |                      stata nominata una delle 100 Eccellenze Italiane.                      |    'PERSON'), ('Eccellenze Italiane',    |
# |                      Visita il nostro shop online e scegli lo stile che                     |  'PERSON'), ('scegli lo stile che più',  |
# |                          più ti si adatta. Acquista adesso i nostri                         |    'PERSON'), ('Acquista', 'PERSON')]    |
# |                                     accessori di lusso.                                     |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      Designer sunglasses & eyeglasses that everyone can                     |    [('over 100', 'CARDINAL'), ('Privé    |
# |                         afford & flaunt proudly. Check out over 100                         |    Revaux Eyewear', 'ORG'), ('today',    |
# |                       handcrafted & polarized frames from Privé Revaux                      |                 'DATE')]                 |
# |                               Eyewear. Reframe yourself today!                              |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                          We specialize in providing an exceptional                          | [('100%', 'PERCENT'), ('Funko', 'ORG'),  |
# |                      collecting experience for all collectors. We carry                     |    ('Banpresto', 'ORG'), ('Good Smile    |
# |                      100% authentic products from the most prestigious                      |   Company', 'ORG'), ('Tokyo Zerostar',   |
# |                         brands such as Funko, Banpresto, Good Smile                         |  'GPE'), ('Bandai', 'GPE'), ('Disney',   |
# |                       Company, Tokyo Zerostar, Bandai, Disney and much                      |        'ORG'), ('2017', 'DATE')]         |
# |                        more. The world of collectibles in the palm of                       |                                          |
# |                               your hand. Established in 2017.                               |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                       Cut + Clarity offers personalized jewelry; made                       |   [('Cut + Clarity', 'ORG'), ('today',   |
# |                       for you, by you. Real Women. Real Stories. Real                       |                 'DATE')]                 |
# |                      Jewelry. Shop our custom jewelry today. It's your                      |                                          |
# |                                 journey, let it be personal.                                |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      At Amuderya, explore a world of innovative gadgets                     |          [('Amuderya', 'ORG')]           |
# |                        & gears, electronics, health & safety and pet                        |                                          |
# |                       products. Shop now and grab amazing offers this                       |                                          |
# |                                       festive season.                                       |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                       Wabisabi Learning is the source for exceptional                       |    [('Wabisabi Learning', 'PERSON')]     |
# |                      educational resources. Buy books, guides, posters                      |                                          |
# |                        and more for your school or classroom. Teacher                       |                                          |
# |                         resources and lesson planning, professional                         |                                          |
# |                       learning, growth mindset, critical thinking and                       |                                          |
# |                                            more.                                            |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      Online's Frum Shopping Mall The Frum Shopping Mall                     |       [('Online', 'WORK_OF_ART')]        |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                       Original art for your original soul. I have art                       |                    []                    |
# |                      for your walls, stickers, t-shirts, and more. I am                     |                                          |
# |                        an independent artist offering pieces of many                        |                                          |
# |                       different varieties for sale. Please contact me                       |                                          |
# |                                 for commissions. Thank you.                                 |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                       Abby Rose Design (ARD) specializes in beautiful                       |     [('Abby Rose Design', 'PERSON')]     |
# |                       ecommerce websites, with a focus on the Shopify                       |                                          |
# |                                          platform.                                          |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                       A contemporary spin on traditional golf wear for                      |     [('10%', 'PERCENT'), ('American      |
# |                       men with 10% of each and every sale benefitting                       |            Veterans', 'ORG')]            |
# |                            American Veterans and their families.                            |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                         Discover a collection of bohemian inspired,                         |   [('EZRA &', 'ORG'), ('ARLO', 'ORG')]   |
# |                       handmade macramé items. Home decor, jewelry, and                      |                                          |
# |                      so much more. Add beauty and utility to your life                      |                                          |
# |                            with EZRA &amp; ARLO. &lt;&lt;&gt;&gt;                           |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                         BB DAKOTA: women's clothing brand, fashion,                         |             [('BB', 'GPE')]              |
# |                        clothing, dresses, leather jackets, jumpsuits,                       |                                          |
# |                       skirts, shorts, pants and more effortless pieces                      |                                          |
# |                         you'll reach for again and again. Shop Now!                         |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                        POM pepper spray is the next generation self-                        |     [('POM', 'ORG'), ('USA', 'GPE')]     |
# |                       defense product designed to fit seamlessly into                       |                                          |
# |                        your modern lifestyle. Innovative in quality,                        |                                          |
# |                       performance and safety, we put the power in your                      |                                          |
# |                      hands to be adventurous and fearless with Peace of                     |                                          |
# |                                    Mind. Made in the USA.                                   |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      Collagen infused tea drinks in refreshing flavors.                     |      [('Collagen', 'ORG'), ('3000',      |
# |                        Each drink contains 3000mg of collagen, packed                       |               'CARDINAL')]               |
# |                       with vitamins and minerals, to nourish your body                      |                                          |
# |                                          and skin.                                          |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+
# |                      Welcome to Supreme Digital Gadgets Official Online                     |   [('Supreme Digital Gadgets', 'ORG')]   |
# |                        Store.Buy online high quality and latest cool                        |                                          |
# |                        digital gadgets and we offer worldwide express                       |                                          |
# |                                          shipping.                                          |                                          |
# +---------------------------------------------------------------------------------------------+------------------------------------------+

# %% [markdown]
# ## Exercise: Observations
#
# What are your observations in terms of perceived performance:
#
# ### Performance
#
# ...
#
# ### Model Behavior
#
# ...
#
# What do you assume to be the root cause of these observations?
#
# ### Potential Cause I
# ...
#
# ### Potential Cause II
# ...

# %% [markdown]
# ## Exercise: Keyphrase Extraction on Shopify Descriptions

# %%
# This install pytextrank, a library focused on the extraction of keywords (the most important concepts) from text.
pip install pytextrank
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytextrank
#   Downloading pytextrank-3.2.4-py3-none-any.whl (30 kB)
# Requirement already satisfied: spacy>=3.0 in /usr/local/lib/python3.7/dist-packages (from pytextrank) (3.4.3)
# Collecting pygments>=2.7.4
#   Downloading Pygments-2.13.0-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 28.4 MB/s
# Collecting graphviz>=0.13
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 4.2 MB/s
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.7/dist-packages (from pytextrank) (1.7.3)
# Requirement already satisfied: networkx[default]>=2.6 in /usr/local/lib/python3.7/dist-packages (from pytextrank) (2.6.3)
# Collecting icecream>=2.1
#   Downloading icecream-2.1.3-py2.py3-none-any.whl (8.4 kB)
# Collecting asttokens>=2.0.1
#   Downloading asttokens-2.2.0-py2.py3-none-any.whl (26 kB)
# Collecting executing>=0.3.1
#   Downloading executing-1.2.0-py2.py3-none-any.whl (24 kB)
# Collecting colorama>=0.3.9
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from asttokens>=2.0.1->icecream>=2.1->pytextrank) (1.15.0)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.7/dist-packages (from networkx[default]>=2.6->pytextrank) (1.3.5)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.7/dist-packages (from networkx[default]>=2.6->pytextrank) (1.21.6)
# Collecting matplotlib>=3.3
#   Downloading matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 44.7 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->networkx[default]>=2.6->pytextrank) (21.3)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      |████████████████████████████████| 965 kB 35.6 MB/s
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->networkx[default]>=2.6->pytextrank) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->networkx[default]>=2.6->pytextrank) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->networkx[default]>=2.6->pytextrank) (7.1.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->networkx[default]>=2.6->pytextrank) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->networkx[default]>=2.6->pytextrank) (2.8.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib>=3.3->networkx[default]>=2.6->pytextrank) (4.1.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1->networkx[default]>=2.6->pytextrank) (2022.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (1.0.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (3.0.10)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (4.64.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (57.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (2.23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (3.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (2.0.7)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (0.7.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (0.8.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (2.11.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (1.10.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (8.1.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (1.0.9)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (2.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (2.4.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (3.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (0.10.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy>=3.0->pytextrank) (3.10.0)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy>=3.0->pytextrank) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (1.24.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.7/dist-packages (from thinc<8.2.0,>=8.1.0->spacy>=3.0->pytextrank) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.7/dist-packages (from thinc<8.2.0,>=8.1.0->spacy>=3.0->pytextrank) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.8.0,>=0.3.0->spacy>=3.0->pytextrank) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy>=3.0->pytextrank) (2.0.1)
# Installing collected packages: fonttools, pygments, matplotlib, executing, colorama, asttokens, icecream, graphviz, pytextrank
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.6.1
#     Uninstalling Pygments-2.6.1:
#       Successfully uninstalled Pygments-2.6.1
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.10.1
#     Uninstalling graphviz-0.10.1:
#       Successfully uninstalled graphviz-0.10.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# Successfully installed asttokens-2.2.0 colorama-0.4.6 executing-1.2.0 fonttools-4.38.0 graphviz-0.20.1 icecream-2.1.3 matplotlib-3.5.3 pygments-2.13.0 pytextrank-3.2.4

# %%
import spacy
import pytextrank

nlp = spacy.load('en_core_web_sm')
nlp.add_pipe("textrank")

# %%
sampled_df = shopify_desc_df.sample(n=5)
print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
for site_desc, site_title in zip(sampled_df['Site Description'], sampled_df['Site Title']):
    doc = nlp(site_desc)
    print(site_title)
    print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    for p in doc._.phrases[:5]:
        print('{:.4f} {:5d}  {}'.format(p.rank, p.count, p.text))
        print(p.chunks)
    print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Modern Farmhouse Style Home Decor – The Cozy Nest
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0.2195     1  farmhouse decor
# [farmhouse decor]
# 0.2070     1  modern farmhouse decor
# [modern farmhouse decor]
# 0.1994     1  rustic decor
# [rustic decor]
# 0.1992     1  tabletop decor
# [tabletop decor]
# 0.1984     1  industrial decor
# [industrial decor]
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Shape Concept Fajas Colombianas
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0.2226     1  affordable prices
# [affordable prices]
# 0.1956     1  Shape Concept Fajas Colombianas Premium
# [Shape Concept Fajas Colombianas Premium]
# 0.1038     1  the highest quality products
# [the highest quality products]
# 0.0578     1  our customers
# [our customers]
# 0.0000     2  We
# [We, We]
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# SomniFix | Gentle Mouth Strips for Better, Quieter Sleep
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0.2058     1  partner sleep disruption
# [partner sleep disruption]
# 0.1821     3  sleep
# [sleep, sleep, sleep]
# 0.1654     1  dry mouth
# [dry mouth]
# 0.1503     1  Mouth breathing
# [Mouth breathing]
# 0.1503     1  mouth breathing
# [mouth breathing]
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# COMRAD | Energizing Compression Socks For Women and Men
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0.1695     1  men
# [men]
# 0.1618     1  compression socks
# [compression socks]
# 0.1413     1  pain
# [pain]
# 0.1321     1  varicose veins
# [varicose veins]
# 0.1276     1  women
# [women]
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Restaurant Equipment Online | Warehouse Restaurant Deals | Warehou...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0.1901     1  equipment
# [equipment]
# 0.1521     1  top-notch commercial restaurant supplies
# [top-notch commercial restaurant supplies]
# 0.1334     1  Merchandiser
# [Merchandiser]
# 0.1248     2  Combi Ovens
# [Combi Ovens, Combi Ovens]
# 0.1137     1  Warehouse Restaurant Deals
# [Warehouse Restaurant Deals]
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# ## Exercise: Observations
#
# What are your observations in terms of perceived performance.
# Following the impressions from the first exercise, try to repeat the extraction process with a variety of different models.
#
# ### Performance
#
# ...
#
# ### Model Behavior
#
# ...
#
# What do you assume to be the root cause of these observations?
#
# ### Potential Cause I
# ...
#
# ### Potential Cause II
# ...
